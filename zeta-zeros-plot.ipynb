# %% [markdown]
# I'm trying to find the formula of the zeta function used to plot this graph:

# %% [markdown]
# ![Zeros.png](attachment:fe97a23d-abaa-4a0d-8f93-389b3debf809.png)

# %% [markdown]
# This is taken from Wikipedia [Riemann Zeta Function](https://en.wikipedia.org/wiki/Riemann_zeta_function). It was created in Mathematica by `Slonzor` in 2008.

# %% [markdown]
# This is his Mathematica code (added under the image in Wikipedia):

# %% [markdown]
# Show[Plot[{Re[Zeta[1/2+I x]], Im[Zeta[1/2+I x]]}, {x,-30, 30},AxesLabel->{"x"} , PlotStyle->{Red, Blue}, Ticks->{Table[4x-28,{x,0,14}]}, ImageSize->{800,600}], Graphics[Text[Style[\[DoubleStruckCapitalR][\[Zeta][ I x + "1/2"]],14,Red ,Background ->White],{-22,2.6} ]], Graphics[Text[Style[\[GothicCapitalI][\[Zeta][ I x + "1/2"]],14,Blue ,Background ->White],{-14,2.6} ]]]

# %% [markdown]
# He is using Mathematica's built in function `zeta`:
#
# `Show[Plot[{Re[Zeta[1/2+I x]], Im[Zeta[1/2+I x]]}, ... ]]]`

# %% [markdown]
# [Wolfram Documentation for this function](https://reference.wolfram.com/language/ref/Zeta.html) states:
# > Mathematical function, suitable for both symbolic and numerical manipulation.

# %% [markdown]
# Wolfram documentation lists two zeta function:
#
# > Zeta[s]
# >
# > gives the Riemann zeta function TemplateBox[{s}, Zeta].
#
# > Zeta[s,a]
# >
# > gives the generalized Riemann zeta function TemplateBox[{s, a}, Zeta2].

# %% [markdown]
# I assume that "generalized Riemann zeta function" is "Hurwith zeta function". [This MathWorld page](https://mathworld.wolfram.com/HurwitzZetaFunction.html) has information about zeta functions used in Mathematica. Is it possible to infer from this information the exact formula used by Mathematica to draw this plot?
#
# I'm interested to know because I'll try to plot it in Python, if possible.
